# %%
print("hello git world")
# Out:
# hello git world

# %%
# !jupyter nbconvert --to markdown hello_git.ipynb
# Out:
# [NbConvertApp] Converting notebook hello_git.ipynb to markdown
# [NbConvertApp] Writing 82 bytes to hello_git.md
